# %% [markdown]
# ## First Problem

# %%
def reverse_words(s):
    ''' Function used to reverse the given string
    
    :param str: the string to be reversed
    :return reversed: the reverse of the given string'''
    my_list = s.split(' ')
    result =' '.join(my_list[::-1])
    return result
s ='The greatest victory is that which requires no battle'
reverse_words(s)
# Out:
# 'battle no requires which that is victory greatest The'

# %% [markdown]
# ## Second Problem

# %%
def are_you_playing_banjo(name):
    ''' a function which answers the question "Are you playing banjo?"
    
    :param name: the name of the person to be checked
    return: if he play banjo or not'''

    if name.startswith('r') or name.startswith('R'):
        return f'{name} plays banjo'
    else:
        return f'{name} does not play banjo'

are_you_playing_banjo('Ramy')
# Out:
# 'Ramy plays banjo'

# %% [markdown]
# ## Third Problem

# %%
def twoSum( nums, target):
        """Given an array of integers nums and an integer target, 
        return indices of the two numbers such that they add up to target.

        :param nums: List of numbers.
        :param target: the number we get its sum from nums
        :return: list with the indecies of the values their sum equal the target
        """
        result =[]
        flag = False
        for i in range(len(nums)-1):
                
                j =len(nums)-1
                while j > i:
                        if nums[i]+nums[j] == target:  
                                result.append(i)
                                result.append(j)
                                flag =True
                                break
                        j = j-1
                if flag ==True:
                        break
        return result
twoSum([3,2,4],6)
# Out:
# [1, 2]

# %% [markdown]
# Another better solution

# %%
def twoSum( nums, target):
        """Given an array of integers nums and an integer target, 
        return indices of the two numbers such that they add up to target.

        :param nums: List of numbers.
        :param target: the number we get its sum from nums
        :return: list with the indecies of the values their sum equal the target
        """
        num_map ={}
        for i ,num in enumerate(nums):
                value = target - num
                if value in num_map:
                        return [num_map[value],i]
                num_map[num]=i
        return []
                       
    
twoSum([3,2,4],6)
# Out:
# [1, 2]

# %% [markdown]
# ## Fourth Problem

# %%
class ListNode(object):
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

class Solution(object):       
    def addTwoNumbers(self, l1, l2):
        """Function add the numbers in the two linked list

        :param l1: the first list
        :param l2: the second list
        :return: the output sum of the two lists
        """
        result 
        index =0
        remainder=0
        while min(len(l1) , len(l2)):
            value = l1[index]+l2[index]+remainder
            remainder = value //10
            result.append(value % 10)
            l1.pop(index)
            l2.pop(index)

        while len(l1):
            value = l1[index]+remainder
            remainder = value // 10
            result.append(value % 10)
            l1.pop(index)
            
        while len(l2):
            value = l2[index]+remainder
            remainder = value // 10
            result.append(value % 10)
            l2.pop(index)
        if remainder > 0:
            result.append(remainder)
        return result


        
sol =Solution()
sol.addTwoNumbers([2,4,3],[5,6,4])
# Out:
# [7]
# [7, 0]
# [7, 0, 8]
# [7, 0, 8]
