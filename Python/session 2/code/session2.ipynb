# %%
list_one =[1 ,2, 3 ,4 ,"amit", "learning" ,True ,[1 ,2 ,3 ,"True" ,["ml" , "dl" ,"ds"]]]
print(type(list_one))
# Out:
# <class 'list'>

# %%
print(list_one[0])
print(list_one[7][2])
# Out:
# 1
# 3

# %%
list_2 = ["amit" ,"learning" ,"python"]
list_2.append("depi")
list_2
# Out:
# ['amit', 'learning', 'python', 'depi']

# %%
list_2.insert(0,"depi")
list_2
# Out:
# ['depi', 'depi', 'amit', 'learning', 'python', 'depi']

# %%
list_1 =[ 1,2 ,3 ,4]
list_1.extend(list_2)
list_1.remove(1)
list_1
# Out:
# [2, 3, 4, 'depi', 'depi', 'amit', 'learning', 'python']

# %%
print(list_2)
list_2.pop()
print(list_2)
# Out:
# ['depi', 'depi', 'amit', 'learning', 'python', 'depi']
# ['depi', 'depi', 'amit', 'learning', 'python']

# %%
list_3 =[1,2,3]
list_3*2
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
list_3 =[1,2,3]
len(list_3)
# Out:
# 3

# %%
ans =input()
list_1 =["learning" ,"amit" ,"ml" ,"depi","dl"]
list_1.remove(age)
list_1
# Out:
# ['learning', 'ml', 'depi', 'dl']

# %%
tuble_1 =("amit" ,"learning" ,"depi")
list(tuble_1)
type(tuble_1)
# Out:
# tuple

# %%
x= 5
y =7

print(f"the sum is {x+y}")
print(f"the rpoduct is {x*y}")
print(f"the division is {x/y}")
print(f"the subtraction is {x-y}")
# Out:
# the sum is 12
# the rpoduct is 35
# the division is 0.7142857142857143
# the subtraction is -2

# %%
grade =input("inter grade: ")
grade =int(grade)
if(grade >90) and (grade <=100):
    print("A")
elif(grade >80) and (grade <=90):
    print("B")
elif(grade >70) and (grade <=80):
    print("C")
elif(grade >50) and (grade <=70):
    print("D")
elif(grade >50) and (grade >=0):
    print("F")
else:
    print("please add the grade from 0 to 100")
# Out:
# B

# %%
for i in range(5):
    if i ==2:
        pass
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(5):
    if i == 2:
        continue
    print(i)
# Out:
# 0
# 1
# 3
# 4
