# %%
print("hello world ")
# Out:
# hello world

# %%
'''
mohamed
'''
print ("hello")
# Out:
# hello

# %%
print("my name is {0} ,my age is {1}".format("mohamed" , 20))
print("my name is {} ,my age is {}".format("mohamed" , 20))
print("my name is {x} ,my age is {y}".format(x ="mohamed" , y =20))
# Out:
# my name is mohamed ,my age is 20
# my name is mohamed ,my age is 20
# my name is mohamed ,my age is 20

# %%
name ="Mohamed"
age = 20
learning = "AI/ML"
print("my name is {} and my age is {} and I engaged to learn {}".format(name, age, learning))
# Out:
# my name is Mohamed and my age is 20 and I engaged to learn AI/ML

# %%
name ="Amit learning"
print(name[5:10:1])
# Out:
# learn

# %%
name ="welcome into DEPI round 4 ML "
print(name.split())
spletter = name.split()

sent = ' '.join(spletter)
print(sent)
# Out:
# ['welcome', 'into', 'DEPI', 'round', '4', 'ML']
# welcome into DEPI round 4 ML

# %%
print(name.startswith("hello"))
print(name.startswith("welcome"))
# Out:
# False
# True

# %%
print("my name is \n mohamed")
print("my name is \t mohamed")
print("my name is\b  mohamed")
print("my name is \"mohamed\"")
# Out:
# my name is
#  mohamed
# my name is 	 mohamed
# my name i  mohamed
# my name is "mohamed"

# %%
len(name)
# Out:
# 29

# %%
s ="       depi"
print(s.strip())
# Out:
# depi
