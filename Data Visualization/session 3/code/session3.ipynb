# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

s=pd.Series([1,2,3,4])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
s = pd.Series([1,2,3,4] ,index =["a" ,"b" ,"c" ,"d"])
s
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
data = [[1,444,"abc"],
        [2,555,"def"],
        [3,666,"ghi"],
        [4,444,"xyz"]]
df = pd.DataFrame(data,columns= ['id' ,'salary','dept'])
display(df)
x = df.columns
index =['r1' ,'r2' ,'r3' ,'r4']
df.index =index
df
# Out:
#    id  salary dept
# 0   1     444  abc
# 1   2     555  def
# 2   3     666  ghi
# 3   4     444  xyz
#     id  salary dept
# r1   1     444  abc
# r2   2     555  def
# r3   3     666  ghi
# r4   4     444  xyz

# %%
df.dtypes
# Out:
# id        int64
# salary    int64
# dept        str
# dtype: object

# %%
df['dept'].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
def chk(df ,ty):
    return df[ty].dtype
chk(df ,'salary')
# Out:
# dtype('int64')

# %%
df['dept'] =df['dept'].astype('category')
df.dtypes
# Out:
# id           int64
# salary       int64
# dept      category
# dtype: object

# %%
df['salary'].nunique()
# Out:
# 3

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 4 entries, r1 to r4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      4 non-null      int64
#  1   salary  4 non-null      int64
#  2   dept    4 non-null      category
# dtypes: category(1), int64(2)
# memory usage: 304.0+ bytes

# %%
df['salary'].values
# Out:
# array([444, 555, 666, 444])

# %%
df.replace(555,'ali' )
# Out:
#     id salary dept
# r1   1    444  abc
# r2   2    ali  def
# r3   3    666  ghi
# r4   4    444  xyz

# %%
header_col =['index' , 'gender','dept','postal_cod']
data =pd.read_table('http://bit.ly/movieusers%27', sep ='|', header =None,names =header_col)
data
# Out:
#      index gender           dept postal_cod
# 1       24      M     technician      85711
# 2       53      F          other      94043
# 3       23      M         writer      32067
# 4       24      M     technician      43537
# 5       33      F          other      15213
# ..     ...    ...            ...        ...
# 939     26      F        student      33319
# 940     32      M  administrator      02215
# 941     20      M        student      97229
# 942     48      F      librarian      78209
# 943     22      M        student      77841
#
# [943 rows x 4 columns]

# %%
data = pd.read_csv('http://bit.ly/uforeports')
data
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
data.shape
# Out:
# (18241, 5)

# %%
data['Location'] = data.City +' '+data.State
data
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time                 Location
# 0        6/1/1930 22:00                Ithaca NY
# 1       6/30/1930 20:00           Willingboro NJ
# ...

# %%
data.to_csv('test.csv')

# %%
data.columns = data.columns.str.replace(" ",'_')
data
# Out:
#                        City Colors_Reported Shape_Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time                 Location
# 0        6/1/1930 22:00                Ithaca NY
# 1       6/30/1930 20:00           Willingboro NJ
# ...
