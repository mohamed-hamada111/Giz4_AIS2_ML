# %%
import pandas as pd

# %%
df = pd.read_csv('G:/DEPI/Giz4_AIS2_ML/Data Visualization/session 4/material/train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df =df.drop(['PassengerId','Name' ,'Ticket'],axis =1 )

# %%
dtype = df.dtypes
n_unique =df.nunique()
pd.DataFrame({'Dtypes' :dtype ,'Num_unique' :n_unique}).T
# Out:
#            Survived Pclass  Sex      Age  SibSp  Parch     Fare Cabin Embarked
# Dtypes        int64  int64  str  float64  int64  int64  float64   str      str
# Num_unique        2      3    2       88      7      7      248   147        3

# %%
col =['Survived' ,'Pclass','Sex','SibSp','Parch','Cabin','Embarked']
df[col].astype('category')
# Out:
#     Survived Pclass     Sex SibSp Parch Cabin Embarked
# 0          0      3    male     1     0   NaN        S
# 1          1      1  female     1     0   C85        C
# 2          1      3  female     0     0   NaN        S
# 3          1      1  female     1     0  C123        S
# 4          0      3    male     0     0   NaN        S
# ..       ...    ...     ...   ...   ...   ...      ...
# 886        0      2    male     0     0   NaN        S
# 887        1      1  female     0     0   B42        S
# 888        0      3  female     1     2   NaN        S
# 889        1      1    male     0     0  C148        C
# 890        0      3    male     0     0   NaN        Q
#
# [889 rows x 7 columns]

# %%
dtype = df.dtypes
n_unique =df.nunique()
pd.DataFrame({'Dtypes' :dtype ,'Num_unique' :n_unique}).T
# Out:
#            Survived Pclass  Sex      Age  SibSp  Parch     Fare Cabin Embarked
# Dtypes        int64  int64  str  float64  int64  int64  float64   str      str
# Num_unique        2      3    2       88      7      7      248   147        3

# %%
null = df.isnull().sum()
ratio = null / df.shape[0]
pd.DataFrame({'Null' :null ,'Ratio' :ratio}).T
# Out:
#        Survived  Pclass  Sex         Age  SibSp  Parch  Fare       Cabin  \
# Null        0.0     0.0  0.0  177.000000    0.0    0.0   0.0  687.000000
# Ratio       0.0     0.0  0.0    0.198653    0.0    0.0   0.0    0.771044
#
#        Embarked
# Null   2.000000
# Ratio  0.002245

# %%
from pp import null

ratio = null(df)
ratio
# Out:
#        Survived  Pclass  Sex         Age  SibSp  Parch  Fare       Cabin  \
# Null        0.0     0.0  0.0  177.000000    0.0    0.0   0.0  687.000000
# Ratio       0.0     0.0  0.0    0.198653    0.0    0.0   0.0    0.771044
#
#        Embarked
# Null   2.000000
# Ratio  0.002245

# %%
df = df.dropna(subset =['Embarked'])
df.drop(['Cabin' ],axis= 1)
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [889 rows x 8 columns]

# %%
medien = df['Age'].median()
df['Age'].fillna(medien,inplace =True)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_676\1426501828.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Age'].fillna(medien,inplace =True)
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# ...

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import seaborn as sns

num_col = df.select_dtypes(include='number').columns

plt.figure(figsize=(8, 2 * len(num_col)))

for i, col in enumerate(num_col):
    plt.subplot(len(num_col), 1, i + 1)
    sns.boxplot(x=df[col])
    plt.title(col)

plt.tight_layout()
plt.show()

# %%
for col in num_col:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR =  Q3 - Q1
    lower_fence =Q1 - 1.5*IQR
    upper_fence =Q3 + 1.5*IQR
    lower_outliers =df[df[col]<lower_fence][col].values
    upper_outliers =df[df[col]>upper_fence][col].values
    df[col].replace(lower_outliers , lower_fence ,inplace=True)
    df[col].replace(upper_outliers , upper_fence ,inplace=True)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_676\3344652941.py:9: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df[col].replace(lower_outliers , lower_fence ,inplace=True)
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(107)

# %%
df.drop_duplicates(inplace =True)
